# %%
import matplotlib.pyplot as plt
plt.style.use('../mystyle.mplstyle')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# `````{admonition} Remark
# :class: important
#
# Please be aware that these lecture notes are accessible online in an '**early access**' format. They are actively being developed, and certain sections will be further enriched to provide a comprehensive understanding of the subject matter.
#
# `````

# %% [markdown]
# (_geospatial_data_sources)=
# # Sources of Geospatial Data
#
# Geospatial data describes objects, events, or features with a location on or near the Earth's surface, combining location information with attribute and often temporal data. This data is crucial for various applications, from urban planning and environmental management to disaster response and business analytics.
#
# {numref}`tableC0304_01` demonstrates the diverse range of geospatial data sources available to researchers, practitioners, and the general public. The table illustrates the rich ecosystem of geospatial data sources:
#
# 1. **Government Agencies** provide authoritative, often freely accessible data covering a wide range of topics from topography to environmental monitoring.
#
# 2. **Commercial Providers** offer specialized, often high-resolution data products, particularly useful for business applications and detailed analyses.
#
# 3. **Open-Source Platforms** democratize access to geospatial data, often relying on community contributions to create comprehensive global datasets.
#
# 4. **Environmental Organizations** focus on ecological and climate-related data, crucial for understanding and addressing global environmental challenges.
#
# 5. **Academic Institutions** contribute valuable research data, often covering unique or specialized topics not available from other sources.
#
# 6. **Remote Sensing Sources** provide Earth observation data from satellites and aerial platforms, offering broad coverage and regular updates.
#
# 7. **Specialized Data Providers** cater to specific industries or applications, offering in-depth data for particular sectors.
#
# 8. **Crowd-Sourced Platforms** leverage user-generated content to create dynamic, real-time datasets, particularly useful for rapidly changing information.
#
# ```{table}  Examples of Geospatial Data from Diverse Sources
# :name: tableC0304_01
#
# | Source Type                     | Examples                                                                                              |
# |----------------------------------|-------------------------------------------------------------------------------------------------------|
# | **Government Agencies**          | - [USGS topographic maps](https://www.usgs.gov/products/map-products/topographic-maps) <br> - [Census boundary files](https://www.census.gov/geographies/mapping-files/time-series/geo/carto-boundary-file.html) <br> - [National land cover datasets](https://www.mrlc.gov/national-land-cover-database-nlcd-2016) <br> - [NOAA weather data](https://www.ncdc.noaa.gov/) <br> - [EPA environmental monitoring data](https://www.epa.gov/enviro) <br> - [GeoGratis (NRCan) Canadian geospatial data](https://geogratis.gc.ca/) |
# | **Commercial Providers**         | - [SafeGraph Points of Interest (POI) data](https://www.safegraph.com/) <br> - [Esri demographic data](https://www.esri.com/en-us/arcgis/products/arcgis-online/data) <br> - [Here Technologies street network data](https://developer.here.com/documentation/) <br> - [Mapbox boundaries data](https://www.mapbox.com/) <br> - [DMTI Spatial Canadian location data](https://www.dmtispatial.com/) |
# | **Open-Source Platforms**        | - [OpenStreetMap road and building data](https://www.openstreetmap.org/) <br> - [Natural Earth vector and raster data](https://www.naturalearthdata.com/) <br> - [GADM global administrative boundaries](https://gadm.org/) <br> - [OpenAerialMap imagery](https://openaerialmap.org/) <br> - [OpenAddresses global address data](https://openaddresses.io/) |
# | **Environmental Organizations**  | - [Global Forest Watch deforestation data](https://www.globalforestwatch.org/) <br> - [ClimateCheck climate risk assessments](https://climatecheck.com/) <br> - [World Wildlife Fund ecoregions](https://www.worldwildlife.org/pages/ecoregions) <br> - [UNEP environmental indicators](https://www.unep.org/resources/report/global-environment-outlook-6) <br> - [iNaturalist species observations](https://www.inaturalist.org/) |
# | **Academic Institutions**        | - [CIESIN socioeconomic data](https://ciesin.columbia.edu/) <br> - [WorldPop population estimates](https://www.worldpop.org/) <br> - [ESDAC soil data](https://esdac.jrc.ec.europa.eu/) <br> - [Global Earthquake Model (GEM) seismic hazard maps](https://www.globalquakemodel.org/) <br> - [University of Waterloo Geospatial Centre](https://uwaterloo.ca/library/geospatial) |
# | **Remote Sensing Sources**       | - [Landsat satellite imagery](https://landsat.gsfc.nasa.gov/) <br> - [MODIS land surface temperature data](https://modis.gsfc.nasa.gov/data/dataprod/mod11/) <br> - [Sentinel-1 radar data](https://scihub.copernicus.eu/) <br> - [LiDAR elevation models](https://www.usgs.gov/land-resources/national-geospatial-program/national-lidar-delivery-system) <br> - [Canada Centre for Mapping and Earth Observation](https://www.nrcan.gc.ca/maps-tools-and-publications/maps) |
# | **Specialized Data Providers**   | - [Zillow real estate data](https://www.zillow.com/) <br> - [Foursquare venue data](https://foursquare.com/) <br> - [AccuWeather historical weather data](https://www.accuweather.com/en/us/accuweather-api) <br> - [TomTom traffic data](https://www.tomtom.com/en_gb/traffic/) <br> - [Dun & Bradstreet business locations](https://www.dnb.com/) |
# | **Crowd-Sourced Platforms**      | - [Waze user-reported traffic incidents](https://www.waze.com/) <br> - [OpenWeatherMap weather observations](https://openweathermap.org/) <br> - [Mapillary street-level imagery](https://mapillary.com/) <br> - [OpenSky Network flight tracking data](https://opensky-network.org/) |
#
# ```
